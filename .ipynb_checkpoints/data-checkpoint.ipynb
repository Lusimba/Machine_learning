# %%
import numpy as np
from scipy import sparse
data  = np.ones(4)
row_i = np.arange(4)
col_i = np.arange(4)
eye_c = sparse.coo_matrix(data, (row_i, col_i))
print(eye_c)
# Out:
#   (0, 0)	1.0
#   (0, 1)	1.0
#   (0, 2)	1.0
#   (0, 3)	1.0

# %%
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x, y, marker="x")

# %%
#Pandas
import pandas as pd
clients = {
    'Name':["Lucy","John","Anna","Peter"],
    'City':["Nairobi", "Mombasa", "Malindi", "Berlin"],
    'Age': [34, 12, 45, 56]
}
p_data = pd.DataFrame(clients)
display(p_data[p_data.Age>30])
# Out:
#     Name     City  Age
# 0   Lucy  Nairobi   34
# 2   Anna  Malindi   45
# 3  Peter   Berlin   56

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.20.3

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()
print("The keys are: \n {}" .format(iris_dataset['DESCR'][300:400]))
# Out:
# The keys are:
#  idth in cm
#         - petal length in cm
#         - petal width in cm
#         - class:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state = 0)
print (y_test.shape)
# Out:
# (38,)

# %%
iris_dataframe = pd.DataFrame(X_train, columns = iris_dataset.feature_names)
grr = pd.plotting.scatter_matrix(iris_dataframe, c = y_train, figsize = (15,15), marker = 'z', hist_kwds = {'bins':20},s =60, alpha = .8)
